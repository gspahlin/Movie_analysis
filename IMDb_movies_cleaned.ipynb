# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as py

#The data types were added to stop pandas from guessing the data type
movie_database = pd.read_csv('desktop/IMDb_movies.csv', dtype={"imdb_title_id":str, 'year':str})

movie_database.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     12/26/1906    Biography, Crime, Drama        70         Australia
# 2  1911      8/19/1911                      Drama        53  Germany, Denmark
# 3  1912     11/13/1912             Drama, History       100               USA
# 4  1911       3/6/1911  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
movie_db_df = movie_database[["imdb_title_id", "title", "year", "date_published", "genre",
                             "duration", "country", "language", "director", "avg_vote", 
                             "votes", "reviews_from_users", "reviews_from_critics"]].copy()

movie_db_df.head()
# Out:
#   imdb_title_id                        title  year date_published  \
# 0     tt0000009                   Miss Jerry  1894     1894-10-09
# 1     tt0000574  The Story of the Kelly Gang  1906     12/26/1906
# 2     tt0001892               Den sorte drøm  1911      8/19/1911
# 3     tt0002101                    Cleopatra  1912     11/13/1912
# 4     tt0002130                    L'Inferno  1911       3/6/1911
#
#                        genre  duration           country language  \
# 0                    Romance        45               USA     None
# 1    Biography, Crime, Drama        70         Australia     None
# 2                      Drama        53  Germany, Denmark      NaN
# 3             Drama, History       100               USA  English
# 4  Adventure, Drama, Fantasy        68             Italy  Italian
#
#                               director  avg_vote  votes  reviews_from_users  \
# 0                      Alexander Black       5.9    154                 1.0
# ...

# %%
movie_db_df.describe()
# Out:
#            duration      avg_vote         votes  reviews_from_users  \
# count  85855.000000  85855.000000  8.585500e+04        78258.000000
# mean     100.351418      5.898656  9.493490e+03           46.040826
# std       22.553848      1.234987  5.357436e+04          178.511411
# min       41.000000      1.000000  9.900000e+01            1.000000
# 25%       88.000000      5.200000  2.050000e+02            4.000000
# 50%       96.000000      6.100000  4.840000e+02            9.000000
# 75%      108.000000      6.800000  1.766500e+03           27.000000
# max      808.000000      9.900000  2.278845e+06        10472.000000
#
#        reviews_from_critics
# count          74058.000000
# mean              27.479989
# std               58.339158
# min                1.000000
# 25%                3.000000
# 50%                8.000000
# 75%               23.000000
# max              999.000000

# %%
dupe = movie_db_df.duplicated()

dupe = dupe.sort_values(ascending = False)

dupe
# Out:
# 85854    False
# 28610    False
# 28612    False
# 28613    False
# 28614    False
#          ...
# 57237    False
# 57238    False
# 57239    False
# 57240    False
# 0        False
# Length: 85855, dtype: bool

# %%
movie_db_df.to_csv('desktop/IMDb_movies_cleaned.csv', index = False)

# %%
#we used the unicode_escape encoding because utc 8 didn't work because of the character set
movie_fin = pd.read_csv('desktop/opening_box_office_domestic_50m.csv', encoding = 'unicode_escape')

movie_fin.head()
# Out:
#    Year                                        Film  Opening     Weekend  \
# 0  1983  Star Wars: Episode VI - Return of the Jedi  59305165  May 27-30
# 1  1983                                Superman III  56837690    Jul 1-4
# 2  1983                                     Jaws 3D  52212400  Jul 22-24
# 3  1984        Indiana Jones and the Temple of Doom  62680115  May 25-28
# 4  1984         Star Trek III: The Search for Spock  50208004  May 25-28
#
#           Distributor      Budget
# 0    20th Century Fox  32500000.0
# 1        Warner Bros.  39000000.0
# 2  Universal Pictures  20500000.0
# 3  Paramount Pictures  28000000.0
# 4  Paramount Pictures  17000000.0

# %%
#we rewrote the file to a csv to make it easer to read in to future notebooks

movie_fin.to_csv("desktop/mov_opening_rev.csv", index = False)

# %%
mf = pd.read_csv("desktop/mov_opening_rev.csv")

mf.head()
# Out:
#    Year                                        Film  Opening     Weekend  \
# 0  1983  Star Wars: Episode VI - Return of the Jedi  59305165  May 27-30
# 1  1983                                Superman III  56837690    Jul 1-4
# 2  1983                                     Jaws 3D  52212400  Jul 22-24
# 3  1984        Indiana Jones and the Temple of Doom  62680115  May 25-28
# 4  1984         Star Trek III: The Search for Spock  50208004  May 25-28
#
#           Distributor      Budget
# 0    20th Century Fox  32500000.0
# 1        Warner Bros.  39000000.0
# 2  Universal Pictures  20500000.0
# 3  Paramount Pictures  28000000.0
# 4  Paramount Pictures  17000000.0
