# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns

m_df = pd.read_csv("desktop/MSU_Data_bootcamp/Movie_analysis/IMDb_movies_cleaned.csv", dtype={"imdb_title_id":str, 'year':str})

mrev_df = pd.read_csv("desktop/MSU_Data_bootcamp/Movie_analysis/mov_opening_rev.csv")

m_df.head()
# Out:
#   imdb_title_id                        title  year date_published  \
# 0     tt0000009                   Miss Jerry  1894     1894-10-09
# 1     tt0000574  The Story of the Kelly Gang  1906     12/26/1906
# 2     tt0001892               Den sorte drøm  1911      8/19/1911
# 3     tt0002101                    Cleopatra  1912     11/13/1912
# 4     tt0002130                    L'Inferno  1911       3/6/1911
#
#                        genre  duration           country language  \
# 0                    Romance        45               USA     None
# 1    Biography, Crime, Drama        70         Australia     None
# 2                      Drama        53  Germany, Denmark      NaN
# 3             Drama, History       100               USA  English
# 4  Adventure, Drama, Fantasy        68             Italy  Italian
#
#                               director  avg_vote  votes  reviews_from_users  \
# 0                      Alexander Black       5.9    154                 1.0
# 1                         Charles Tait       6.1    589                 7.0
# 2                            Urban Gad       5.8    188                 5.0
# 3                   Charles L. Gaskill       5.2    446                25.0
# 4  Francesco Bertolini, Adolfo Padovan       7.0   2237                31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0

# %%
#this is a calculation of user review stats of movies by genre
g_avg_vote_df = m_df[['genre', 'avg_vote']].copy()

gen_vote_stats = g_avg_vote_df.groupby('genre').agg(
    mean = pd.NamedAgg(column = 'avg_vote', aggfunc = 'mean'),
    median = pd.NamedAgg(column = 'avg_vote', aggfunc = 'median'),
    standard_deviation = pd.NamedAgg(column = 'avg_vote', aggfunc = 'std'),
    movie_count= pd.NamedAgg(column = 'avg_vote', aggfunc = 'count')
)

gvs_means = gen_vote_stats.sort_values(by = ['mean'], ascending = False)

gvs_means
# Out:
#                               mean  median  standard_deviation  movie_count
# genre
# Musical, Comedy, Family        8.7     8.7                 NaN            1
# Music, Musical                 8.5     8.5                 NaN            1
# Family, Sci-Fi, Adventure      8.4     8.4                 NaN            1
# Fantasy, Musical, Sci-Fi       8.1     8.1                 NaN            1
# Fantasy, Drama, Romance        8.0     8.0                 NaN            1
# ...                            ...     ...                 ...          ...
# Horror, Drama, Thriller        2.6     2.6                 NaN            1
# Drama, Horror, Reality-TV      2.4     2.4                 NaN            1
# Horror, Reality-TV, Thriller   2.1     2.1                 NaN            1
# Action, Sci-Fi, War            1.5     1.2            0.608276            3
# Comedy, History, Horror        1.1     1.1                 NaN            1
#
# [1257 rows x 4 columns]

# %%
#This cell is to identify the most common movie genres and look at their average scores
gvs_counts = gen_vote_stats.sort_values(by = ["movie_count"], ascending = False)

gvs_counts.head(25)

gvs_mc = gvs_counts.head(25).copy()

gvs_mc.sort_values(by = ['mean'], ascending = False)

gvs_mc
# Out:
#                                mean  median  standard_deviation  movie_count
# genre
# Drama                      6.357076    6.50            0.964083        12543
# Comedy                     5.604745    5.80            1.219596         7693
# Comedy, Drama              6.253033    6.40            0.987685         4039
# Drama, Romance             6.338726    6.50            0.954476         3455
# Comedy, Romance            5.888278    6.00            0.999580         2508
# Comedy, Drama, Romance     6.202922    6.30            0.971382         2293
# Horror                     4.386199    4.40            1.277780         2268
# Drama, Thriller            5.813353    5.90            1.111070         1348
# Crime, Drama               6.261579    6.40            1.033780         1343
# Action, Crime, Drama       5.879084    6.00            1.178599         1310
# Thriller                   5.153173    5.10            1.181680         1245
# Horror, Thriller           4.575041    4.60            1.167206         1214
# Crime, Drama, Thriller     6.122331    6.20            1.085543         1021
# Action, Drama              5.739160    5.90            1.303552          881
# Drama, War                 6.610644    6.70            0.875217          761
# Action                     4.929510    5.00            1.303909          715
# Crime, Drama, Mystery      6.247826    6.30            0.969756          667
# Action, Adventure, Drama   5.916776    6.20            1.279369          608
# Action, Adventure, Comedy  5.430693    5.70            1.389351          606
# Comedy, Crime              5.826689    5.95            1.101037          592
# Western                    5.802721    6.00            1.020401          588
# Comedy, Horror             4.691274    4.70            1.189726          573
# Action, Thriller           5.436204    5.50            1.279534          569
# Horror, Mystery, Thriller  5.176418    5.30            1.182898          564
# Comedy, Crime, Drama       6.248307    6.40            0.999000          561

# %%
#this is a calculation of user review stats of movies by country
c_avg_vote_df = m_df[['country', 'avg_vote']].copy()

con_vote_stats = c_avg_vote_df.groupby('country').agg(
    mean = pd.NamedAgg(column = 'avg_vote', aggfunc = 'mean'),
    median = pd.NamedAgg(column = 'avg_vote', aggfunc = 'median'),
    standard_deviation = pd.NamedAgg(column = 'avg_vote', aggfunc = 'std'),
    movie_count= pd.NamedAgg(column = 'avg_vote', aggfunc = 'count')
)

cs_means = con_vote_stats.sort_values(by = ['mean'], ascending = False)

cs_means
# Out:
#                                                    mean  median  \
# country
# Republic of North Macedonia, Poland                 8.5     8.5
# USA, UK, Malta, Morocco                             8.5     8.5
# UK, France, Poland, Germany, USA                    8.5     8.5
# Romania, France, Italy                              8.4     8.4
# Lebanon, USA, France, Cyprus, Qatar, UK             8.4     8.4
# ...                                                 ...     ...
# France, Spain, Belgium, Canada, Mexico              1.6     1.6
# Italy, USA, Spain                                   1.6     1.6
# USA, Australia, India, Hong Kong, UK                1.5     1.5
# India, China, United Arab Emirates, USA, Malaysia   1.3     1.3
# USA, Argentina, South Africa, Japan, Israel         1.1     1.1
#
#                                                    standard_deviation  \
# country
# Republic of North Macedonia, Poland                               NaN
# USA, UK, Malta, Morocco                                           NaN
# UK, France, Poland, Germany, USA                                  NaN
# Romania, France, Italy                                            NaN
# Lebanon, USA, France, Cyprus, Qatar, UK                           NaN
# ...                                                               ...
# France, Spain, Belgium, Canada, Mexico                            NaN
# Italy, USA, Spain                                                 NaN
# USA, Australia, India, Hong Kong, UK                              NaN
# India, China, United Arab Emirates, USA, Malaysia                 NaN
# USA, Argentina, South Africa, Japan, Israel                       NaN
#
#                                                    movie_count
# country
# Republic of North Macedonia, Poland                          1
# USA, UK, Malta, Morocco                                      1
# UK, France, Poland, Germany, USA                             1
# Romania, France, Italy                                       1
# Lebanon, USA, France, Cyprus, Qatar, UK                      1
# ...                                                        ...
# France, Spain, Belgium, Canada, Mexico                       1
# Italy, USA, Spain                                            1
# USA, Australia, India, Hong Kong, UK                         1
# India, China, United Arab Emirates, USA, Malaysia            1
# USA, Argentina, South Africa, Japan, Israel                  1
#
# [4907 rows x 4 columns]

# %%
#This cell is to identify the most common movie genres and look at their average scores
cs_counts = con_vote_stats.sort_values(by = ["movie_count"], ascending = False)

cs_counts.head(25)

cs_mc = cs_counts.head(25).copy()

cs_mc
# Out:
#                   mean  median  standard_deviation  movie_count
# country
# USA           5.556084     5.8            1.284809        28511
# India         6.224880     6.5            1.425698         6065
# UK            5.781099     6.0            1.234406         4111
# Japan         6.536334     6.7            0.968778         3077
# France        6.108838     6.2            0.932513         3055
# Italy         5.818044     6.0            1.078479         2444
# Canada        5.403718     5.5            1.264684         1802
# Germany       5.913324     6.1            1.123625         1396
# Turkey        5.791488     6.1            1.472793         1351
# Hong Kong     6.091203     6.2            0.887462         1239
# Spain         5.775020     6.0            1.018880         1225
# South Korea   6.383772     6.4            0.731617         1103
# Russia        5.664963     6.0            1.374098          802
# Australia     5.677325     5.9            1.108545          785
# Soviet Union  7.125065     7.2            0.685879          766
# Brazil        6.014538     6.3            1.169519          736
# UK, USA       6.274231     6.4            1.034157          683
# Mexico        6.131908     6.4            1.209862          655
# Iran          5.859657     6.0            1.245137          642
# Sweden        5.611415     5.7            1.170015          622
# Poland        6.076384     6.3            1.248835          614
# Denmark       5.812966     5.9            0.999978          563
# Greece        6.086462     6.2            1.131905          554
# China         6.062595     6.3            1.095015          524
# Netherlands   6.017980     6.2            0.886961          495

# %%
#looking at average vote by year
#this sort operation revealed an abberant value preventing year from being a numeric data type
time_df= m_df[['year', 'avg_vote']].copy()

t_df = time_df.groupby('year').mean()

t_df.sort_values(by = 'avg_vote')

t_df
# Out:
#                avg_vote
# year
# 1894           5.900000
# 1906           6.100000
# 1911           6.140000
# 1912           5.980000
# 1913           6.546154
# ...                 ...
# 2017           5.696786
# 2018           5.688609
# 2019           5.791271
# 2020           5.564005
# TV Movie 2019  7.100000
#
# [113 rows x 1 columns]

# %%
#average score grouped by year


t_df.plot(kind = "bar")

# %%
#genre plot

g_plot = gvs_mc[['mean']].copy()

g_plot.plot(kind = "bar", legend = False)

plt.title('Average Score by Genre, Top 25 most common Genres')
plt.ylabel("Average User Score")
plt.xlabel('Genre')
plt.show()

# %%
#this is the row with a screwy year value mentioned above

m_df.loc[m_df['year'] == 'TV Movie 2019']
# Out:
#       imdb_title_id          title           year date_published  \
# 83917     tt8206668  Bad Education  TV Movie 2019  TV Movie 2019
#
#                           genre  duration country language     director  \
# 83917  Biography, Comedy, Crime       108     USA  English  Cory Finley
#
#        avg_vote  votes  reviews_from_users  reviews_from_critics
# 83917       7.1  23973               135.0                  98.0

# %%
#Replacing the bad value with an appropriate one

m_df.replace('TV Movie 2019', '2019', inplace = True)

m_df.iloc[83917]
# Out:
# imdb_title_id                          tt8206668
# title                              Bad Education
# year                                        2019
# date_published                              2019
# genre                   Biography, Comedy, Crime
# duration                                     108
# country                                      USA
# language                                 English
# director                             Cory Finley
# avg_vote                                     7.1
# votes                                      23973
# reviews_from_users                           135
# reviews_from_critics                          98
# Name: 83917, dtype: object

# %%
m_df = m_df.astype({'year':'int64'})

m_df.dtypes
# Out:
# imdb_title_id            object
# title                    object
# year                      int64
# date_published           object
# genre                    object
# duration                  int64
# country                  object
# language                 object
# director                 object
# avg_vote                float64
# votes                     int64
# reviews_from_users      float64
# reviews_from_critics    float64
# dtype: object

# %%
#attempting to plot year by average vote in a scatter plot
#this rendering uses a contour polt from the seaborn module, which seems kind of computationally expensive

plt.scatter(m_df['year'], m_df['avg_vote'], facecolors = "lightgrey")
sns.kdeplot(m_df['year'], m_df['avg_vote'])
plt.xlabel("Year")
plt.ylabel("Average vote")
plt.title('Average User Score for Movies in IMDb')

plt.show()

# %%
#this is a hexbin plot to clarify the very dense scatter plot
#cmap is for colormap, this is a scheme that dictates how the density is shown
#sharex = False makes it so the x labels show up

m_df.plot.hexbin(x = 'year', y = 'avg_vote', gridsize = 15, cmap = 'coolwarm', sharex = False)
plt.xlabel("year")
plt.ylabel("Average Vote")
plt.title('Average User Score for Movies in IMDb')
plt.show()

# %%
#do the same thing with votes (contoured scatter)
plt.scatter(m_df['year'], m_df['votes'], edgecolors = "black")
#sns.kdeplot(m_df['year'], m_df['votes'])
plt.xlabel("year")
plt.ylabel("votes")
plt.title('number of votes for Movies in IMDb')

plt.show()

# %%
m_df.plot.hexbin(x = 'year', y = 'votes', gridsize = 20, cmap = 'coolwarm', sharex = False)
plt.xlabel("year")
plt.ylabel("Votes")
plt.title('Number of Votes for Movies in IMDb')
plt.show()

# %%
vot_df = m_df[["votes"]].copy()

xlimit = 500000

vot_df.hist(bins = 80)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F9151495B0>]],
#       dtype=object)

# %%
#looking at average vote by year
#this sort operation revealed an abberant value preventing year from being a numeric data type
time_df= m_df[['year', 'avg_vote']].copy()

t_df = time_df.groupby('year').mean()

t_df.sort_values(by = 'avg_vote')

t_df
# Out:
#       avg_vote
# year
# 1894  5.900000
# 1906  6.100000
# 1911  6.140000
# 1912  5.980000
# 1913  6.546154
# ...        ...
# 2016  5.658062
# 2017  5.696786
# 2018  5.688609
# 2019  5.791731
# 2020  5.564005
#
# [112 rows x 1 columns]

# %%
#average score grouped by year


t_df.plot(kind = "line")

# %%
#looking at average vote by year
#this sort operation revealed an abberant value preventing year from being a numeric data type
time_tots_df= m_df[['year', 'votes']].copy()

t2_df = time_tots_df.groupby('year').median()

t2_df
# Out:
#       votes
# year
# 1894  154.0
# 1906  589.0
# 1911  162.0
# 1912  305.0
# 1913  548.0
# ...     ...
# 2016  508.5
# 2017  480.0
# 2018  470.0
# 2019  422.0
# 2020  439.0
#
# [112 rows x 1 columns]

# %%
t2_df.plot(kind = "line")
plt.title('Median Votes per Movie by Year')
# Out:
# Text(0.5, 1.0, 'Median Votes per Movie by Year')

# %%
tt3_df= m_df[['year', 'votes']].copy()

t3_df = tt3_df.groupby('year').mean()

t3_df.plot(kind = "line")
plt.title('Mean Votes per Movie by Year')
# Out:
# Text(0.5, 1.0, 'Mean Votes per Movie by Year')

# %%
#scatter plot for duration vs avg vote

plt.scatter(m_df['duration'], m_df['avg_vote'], facecolors = "lightgrey")
sns.kdeplot(m_df['duration'], m_df['avg_vote'])

plt.show()

# %%
m_df.dtypes
# Out:
# imdb_title_id            object
# title                    object
# year                      int64
# date_published           object
# genre                    object
# duration                  int64
# country                  object
# language                 object
# director                 object
# avg_vote                float64
# votes                     int64
# reviews_from_users      float64
# reviews_from_critics    float64
# dtype: object

# %%
#filtering outliers and replotting
#filter didn't work because it doesn't think duration is an integer
#I'm going to decline to work on this one, because it doesn't look like there is much of a correlation anyway based on the 
#plot below

dur_df = m_df[['duration', 'avg_vote']].copy()

#dur_df = dur_df[dur_df['duration' < 200]]
#plt.scatter(dur_df['duration'], dur_df['avg_vote'], facecolors = "lightgrey")
#sns.kdeplot(dur_df['duration'], dur_df['avg_vote'])

#plt.show()

dur_df = dur_df.groupby('duration').mean()

dur_df.plot(kind = "line")

#look for what the outliers for duration are

# %%
gvs_counts.head(50)
# Out:
#                                   mean  median  standard_deviation  \
# genre
# Drama                         6.357076    6.50            0.964083
# Comedy                        5.604745    5.80            1.219596
# Comedy, Drama                 6.253033    6.40            0.987685
# Drama, Romance                6.338726    6.50            0.954476
# Comedy, Romance               5.888278    6.00            0.999580
# Comedy, Drama, Romance        6.202922    6.30            0.971382
# Horror                        4.386199    4.40            1.277780
# Drama, Thriller               5.813353    5.90            1.111070
# Crime, Drama                  6.261579    6.40            1.033780
# Action, Crime, Drama          5.879084    6.00            1.178599
# Thriller                      5.153173    5.10            1.181680
# Horror, Thriller              4.575041    4.60            1.167206
# Crime, Drama, Thriller        6.122331    6.20            1.085543
# Action, Drama                 5.739160    5.90            1.303552
# Drama, War                    6.610644    6.70            0.875217
# Action                        4.929510    5.00            1.303909
# Crime, Drama, Mystery         6.247826    6.30            0.969756
# Action, Adventure, Drama      5.916776    6.20            1.279369
# Action, Adventure, Comedy     5.430693    5.70            1.389351
# Comedy, Crime                 5.826689    5.95            1.101037
# Western                       5.802721    6.00            1.020401
# Comedy, Horror                4.691274    4.70            1.189726
# Action, Thriller              5.436204    5.50            1.279534
# Horror, Mystery, Thriller     5.176418    5.30            1.182898
# Comedy, Crime, Drama          6.248307    6.40            0.999000
# Action, Comedy, Crime         5.884416    6.00            1.073982
# Action, Crime, Thriller       5.775050    5.90            1.298890
# Biography, Drama              6.588664    6.70            0.905714
# Action, Comedy                5.504752    5.60            1.243241
# Crime, Drama, Film-Noir       6.603846    6.60            0.602571
# Drama, Family                 6.429932    6.50            0.992775
# Romance                       5.919362    6.10            1.160524
# Biography, Drama, History     6.751376    6.80            0.868198
# Action, Drama, Thriller       5.709700    5.80            1.192317
# Animation, Adventure, Comedy  6.160839    6.30            1.179322
# Comedy, Drama, Family         6.252029    6.40            1.112484
# Drama, Mystery, Thriller      5.892476    5.90            1.109993
# Drama, History                6.653181    6.70            0.886863
# Drama, Horror, Mystery        5.425594    5.50            1.245183
# Crime, Drama, Romance         6.302432    6.40            0.910028
# Horror, Sci-Fi                4.604607    4.60            1.332273
# Drama, Horror, Thriller       5.047339    5.10            1.192309
# Crime, Thriller               5.755114    5.90            1.149075
# Comedy, Musical               6.078182    6.20            0.945125
# Comedy, Musical, Romance      6.273457    6.35            0.863128
# Comedy, Family                5.516250    5.60            1.286554
# Action, Comedy, Drama         5.816088    5.90            1.219213
# Animation, Action, Adventure  6.625000    6.80            1.034431
# Mystery, Thriller             5.792977    5.80            1.175498
# Action, Drama, Romance        5.837801    6.00            1.151527
#
#                               movie_count
# genre
# Drama                               12543
# Comedy                               7693
# Comedy, Drama                        4039
# Drama, Romance                       3455
# Comedy, Romance                      2508
# Comedy, Drama, Romance               2293
# Horror                               2268
# Drama, Thriller                      1348
# Crime, Drama                         1343
# Action, Crime, Drama                 1310
# Thriller                             1245
# Horror, Thriller                     1214
# Crime, Drama, Thriller               1021
# Action, Drama                         881
# Drama, War                            761
# Action                                715
# Crime, Drama, Mystery                 667
# Action, Adventure, Drama              608
# Action, Adventure, Comedy             606
# Comedy, Crime                         592
# Western                               588
# Comedy, Horror                        573
# Action, Thriller                      569
# Horror, Mystery, Thriller             564
# Comedy, Crime, Drama                  561
# Action, Comedy, Crime                 539
# Action, Crime, Thriller               505
# Biography, Drama                      494
# Action, Comedy                        463
# Crime, Drama, Film-Noir               442
# Drama, Family                         441
# Romance                               439
# Biography, Drama, History             436
# Action, Drama, Thriller               433
# Animation, Adventure, Comedy          429
# Comedy, Drama, Family                 419
# Drama, Mystery, Thriller              412
# Drama, History                        393
# Drama, Horror, Mystery                379
# Crime, Drama, Romance                 370
# Horror, Sci-Fi                        369
# Drama, Horror, Thriller               357
# Crime, Thriller                       352
# Comedy, Musical                       330
# Comedy, Musical, Romance              324
# Comedy, Family                        320
# Action, Comedy, Drama                 317
# Animation, Action, Adventure          312
# Mystery, Thriller                     299
# Action, Drama, Romance                291

# %%
#Genres Anova
#setting dfs of movies by single component genre and average vote

horror_df = m_df[m_df['genre']=="Horror"]['avg_vote']
drama_df = m_df[m_df['genre']=="Drama"]['avg_vote']
comedy_df = m_df[m_df['genre']=="Comedy"]['avg_vote']
action_df = m_df[m_df['genre']=="Action"]['avg_vote']
western_df = m_df[m_df['genre']=="Western"]['avg_vote']
thriller_df = m_df[m_df['genre']=="Thriller"]['avg_vote']
romance_df = m_df[m_df['genre']=="Romance"]['avg_vote']

gen_stat, genp = st.f_oneway(horror_df, drama_df, comedy_df, action_df, western_df, thriller_df, romance_df)

print(f'The p - value is {genp}')
# Out:
# The p - value is 0.0

# %%
#Welches t-test between horror and drama

st.ttest_ind(horror_df, drama_df, equal_var = False)
# Out:
# Ttest_indResult(statistic=-69.94395887619143, pvalue=0.0)

# %%
st.ttest_ind(comedy_df, drama_df, equal_var = False)
# Out:
# Ttest_indResult(statistic=-46.00332937041193, pvalue=0.0)

# %%
genre_plot = {
    "Horror":horror_df, "Drama": drama_df, "Comedy": comedy_df,
    "Action":action_df, "Western":western_df, "Thriller": thriller_df, 
    "Romance": romance_df
}

gp_df = pd.DataFrame(data = genre_plot)

#gp_df

# %%
#boxplot for single designation movie genres

boxplot = gp_df.boxplot(grid = False)

plt.title('Single Designation Movie Genres By Average Score')
plt.ylabel('Average User Score')
plt.xlabel('Genre')

plt.show()

# %%
#histograms of horror and drama movie scores
drama_df.hist()
horror_df.hist()
plt.title('Drama vs. Horror Movies by User Score')
plt.ylabel('Number of Movies with Score')
plt.xlabel('Average User Score')
# Out:
# Text(0.5, 0, 'Average User Score')

# %%
mrev_df.head()
# Out:
#    Year                                        Film  Opening     Weekend  \
# 0  1983  Star Wars: Episode VI - Return of the Jedi  59305165  May 27-30
# 1  1983                                Superman III  56837690    Jul 1-4
# 2  1983                                     Jaws 3D  52212400  Jul 22-24
# 3  1984        Indiana Jones and the Temple of Doom  62680115  May 25-28
# 4  1984         Star Trek III: The Search for Spock  50208004  May 25-28
#
#           Distributor      Budget
# 0    20th Century Fox  32500000.0
# 1        Warner Bros.  39000000.0
# 2  Universal Pictures  20500000.0
# 3  Paramount Pictures  28000000.0
# 4  Paramount Pictures  17000000.0

# %%
#merging the financial information with the IMDb dataframe information

mrev_df.rename(columns = {"Film":"title"}, inplace = True)

m_combine = pd.merge(mrev_df, m_df, on= "title")

m_combine.head()
# Out:
#    Year         title  Opening     Weekend        Distributor      Budget  \
# 0  1983  Superman III  56837690    Jul 1-4       Warner Bros.  39000000.0
# 1  1984  Ghostbusters  60535933   Jun 8-10  Columbia Pictures  30000000.0
# 2  1988      Cocktail  50052220  Jul 29-31        Walt Disney  20000000.0
# 3  1988      Cocktail  50052220  Jul 29-31        Walt Disney  20000000.0
# 4  1988      Cocktail  50052220  Jul 29-31        Walt Disney  20000000.0
#
#   imdb_title_id  year date_published                      genre  duration  \
# 0     tt0086393  1983      6/17/1983  Action, Adventure, Comedy       125
# 1     tt1289401  2016      7/28/2016    Action, Comedy, Fantasy       117
# 2     tt0094889  1988      1/18/1989     Comedy, Drama, Romance       104
# 3     tt1821373  2010     10/22/2010   Drama, Musical, Thriller       111
# 4     tt2168910  2012      7/13/2012     Comedy, Drama, Romance       146
#
#           country                        language         director  avg_vote  \
# 0         UK, USA       English, Italian, Spanish   Richard Lester       5.0
# 1  USA, Australia                         English        Paul Feig       5.2
# 2     USA, Canada  English, Spanish Sign Language  Roger Donaldson       5.9
# 3           India                       Malayalam       Arun Kumar       7.2
# 4       UK, India                           Hindi    Homi Adajania       6.3
#
#     votes  reviews_from_users  reviews_from_critics
# 0   63179               262.0                 119.0
# 1  200067              2203.0                 689.0
# 2   77870               130.0                  60.0
# 3     782                 4.0                   NaN
# 4   13100                64.0                  33.0

# %%
#setting year values as floats so that they can be numeric
m_combine = m_combine.astype({'year':'float64', 'Year':'float64'})

# %%
#checking on data types
m_combine.dtypes
# Out:
# Year                    float64
# title                    object
# Opening                   int64
# Weekend                  object
# Distributor              object
# Budget                  float64
# imdb_title_id            object
# year                    float64
# date_published           object
# genre                    object
# duration                  int64
# country                  object
# language                 object
# director                 object
# avg_vote                float64
# votes                     int64
# reviews_from_users      float64
# reviews_from_critics    float64
# dtype: object

# %%
#using the two year columns to filter merge errors
m_combine_f = m_combine[m_combine['Year'] == m_combine['year']]
m_combine_f
# Out:
#        Year                      title   Opening     Weekend  \
# 0    1983.0               Superman III   56837690    Jul 1-4
# 2    1988.0                   Cocktail   50052220  Jul 29-31
# 7    1989.0                     Batman   93294088  Jun 23-25
# 8    1989.0              Harlem Nights   52044039  Nov 17-19
# 11   1990.0                 Dick Tracy   67952401  Jun 15-17
# ..      ...                        ...        ...        ...
# 442  2019.0  Spider-Man: Far from Home  174209668    Jul 5-7
# 443  2019.0              Downton Abbey  113373910  Sep 20-22
# 449  2019.0                      Joker  142713298    Oct 4-6
# 450  2019.0                     Midway  100490654   Nov 8-10
# 452  2020.0          Bad Boys for Life  148594253  Jan 17-19
#
#             Distributor       Budget imdb_title_id    year date_published  \
# 0          Warner Bros.   39000000.0     tt0086393  1983.0      6/17/1983
# 2           Walt Disney   20000000.0     tt0094889  1988.0      1/18/1989
# 7          Warner Bros.   35000000.0     tt0096895  1989.0     10/20/1989
# 8    Paramount Pictures   30000000.0     tt0097481  1989.0     11/17/1989
# 11          Walt Disney   47000000.0     tt0099422  1990.0      10/5/1990
# ..                  ...          ...           ...     ...            ...
# 442       Sony Pictures  160000000.0     tt6320628  2019.0      7/10/2019
# 443      Focus Features   13000000.0     tt6398184  2019.0     10/24/2019
# 449        Warner Bros.   55000000.0     tt7286456  2019.0      10/3/2019
# 450           Lionsgate  100000000.0     tt6924650  2019.0     11/27/2019
# 452       Sony Pictures   90000000.0     tt1502397  2020.0      2/20/2020
#
#                          genre  duration                        country  \
# 0    Action, Adventure, Comedy       125                        UK, USA
# 2       Comedy, Drama, Romance       104                    USA, Canada
# 7            Action, Adventure       126                        USA, UK
# 8         Comedy, Crime, Drama       116                            USA
# 11       Action, Comedy, Crime       105                            USA
# ..                         ...       ...                            ...
# 442  Action, Adventure, Sci-Fi       129                            USA
# 443             Drama, Romance       122                        UK, USA
# 449     Crime, Drama, Thriller       122                    USA, Canada
# 450   Action, Adventure, Drama       138  China, Hong Kong, Canada, USA
# 452      Action, Comedy, Crime       124                    USA, Mexico
#
#                            language                     director  avg_vote  \
# 0         English, Italian, Spanish               Richard Lester       5.0
# 2    English, Spanish Sign Language              Roger Donaldson       5.9
# 7          English, French, Spanish                   Tim Burton       7.5
# 8                           English                 Eddie Murphy       6.1
# 11                          English                Warren Beatty       6.1
# ..                              ...                          ...       ...
# 442         English, Italian, Czech                    Jon Watts       7.5
# 443                         English               Michael Engler       7.4
# 449                         English                Todd Phillips       8.5
# 450     English, Japanese, Mandarin              Roland Emmerich       6.7
# 452                English, Spanish  Adil El Arbi, Bilall Fallah       6.6
#
#       votes  reviews_from_users  reviews_from_critics
# 0     63179               262.0                 119.0
# 2     77870               130.0                  60.0
# 7    332356               934.0                 229.0
# 8     19829                75.0                  26.0
# 11    56659               194.0                 101.0
# ..      ...                 ...                   ...
# 442  304708              2041.0                 415.0
# 443   35846               441.0                 174.0
# 449  855097             10472.0                 698.0
# 450   57789               946.0                 174.0
# 452  111557              1072.0                 238.0
#
# [305 rows x 18 columns]

# %%
#getting rid of redundant year columns

m_combine_f = m_combine_f.drop('year', 1)

m_combine_f
# Out:
#        Year                      title   Opening     Weekend  \
# 0    1983.0               Superman III   56837690    Jul 1-4
# 2    1988.0                   Cocktail   50052220  Jul 29-31
# 7    1989.0                     Batman   93294088  Jun 23-25
# 8    1989.0              Harlem Nights   52044039  Nov 17-19
# 11   1990.0                 Dick Tracy   67952401  Jun 15-17
# ..      ...                        ...        ...        ...
# 442  2019.0  Spider-Man: Far from Home  174209668    Jul 5-7
# 443  2019.0              Downton Abbey  113373910  Sep 20-22
# 449  2019.0                      Joker  142713298    Oct 4-6
# 450  2019.0                     Midway  100490654   Nov 8-10
# 452  2020.0          Bad Boys for Life  148594253  Jan 17-19
#
#             Distributor       Budget imdb_title_id date_published  \
# 0          Warner Bros.   39000000.0     tt0086393      6/17/1983
# 2           Walt Disney   20000000.0     tt0094889      1/18/1989
# 7          Warner Bros.   35000000.0     tt0096895     10/20/1989
# 8    Paramount Pictures   30000000.0     tt0097481     11/17/1989
# 11          Walt Disney   47000000.0     tt0099422      10/5/1990
# ..                  ...          ...           ...            ...
# 442       Sony Pictures  160000000.0     tt6320628      7/10/2019
# 443      Focus Features   13000000.0     tt6398184     10/24/2019
# 449        Warner Bros.   55000000.0     tt7286456      10/3/2019
# 450           Lionsgate  100000000.0     tt6924650     11/27/2019
# 452       Sony Pictures   90000000.0     tt1502397      2/20/2020
#
#                          genre  duration                        country  \
# 0    Action, Adventure, Comedy       125                        UK, USA
# 2       Comedy, Drama, Romance       104                    USA, Canada
# 7            Action, Adventure       126                        USA, UK
# 8         Comedy, Crime, Drama       116                            USA
# 11       Action, Comedy, Crime       105                            USA
# ..                         ...       ...                            ...
# 442  Action, Adventure, Sci-Fi       129                            USA
# 443             Drama, Romance       122                        UK, USA
# 449     Crime, Drama, Thriller       122                    USA, Canada
# 450   Action, Adventure, Drama       138  China, Hong Kong, Canada, USA
# 452      Action, Comedy, Crime       124                    USA, Mexico
#
#                            language                     director  avg_vote  \
# 0         English, Italian, Spanish               Richard Lester       5.0
# 2    English, Spanish Sign Language              Roger Donaldson       5.9
# 7          English, French, Spanish                   Tim Burton       7.5
# 8                           English                 Eddie Murphy       6.1
# 11                          English                Warren Beatty       6.1
# ..                              ...                          ...       ...
# 442         English, Italian, Czech                    Jon Watts       7.5
# 443                         English               Michael Engler       7.4
# 449                         English                Todd Phillips       8.5
# 450     English, Japanese, Mandarin              Roland Emmerich       6.7
# 452                English, Spanish  Adil El Arbi, Bilall Fallah       6.6
#
#       votes  reviews_from_users  reviews_from_critics
# 0     63179               262.0                 119.0
# 2     77870               130.0                  60.0
# 7    332356               934.0                 229.0
# 8     19829                75.0                  26.0
# 11    56659               194.0                 101.0
# ..      ...                 ...                   ...
# 442  304708              2041.0                 415.0
# 443   35846               441.0                 174.0
# 449  855097             10472.0                 698.0
# 450   57789               946.0                 174.0
# 452  111557              1072.0                 238.0
#
# [305 rows x 17 columns]

# %%
#write data set out to csv

m_combine_f.to_csv('Desktop/financials_w_IMDB.csv', index = False)

# %%
m_combine_fd = m_combine_f.dropna()

m_combine_fd
# Out:
#        Year                      title   Opening     Weekend  \
# 0    1983.0               Superman III   56837690    Jul 1-4
# 2    1988.0                   Cocktail   50052220  Jul 29-31
# 7    1989.0                     Batman   93294088  Jun 23-25
# 8    1989.0              Harlem Nights   52044039  Nov 17-19
# 11   1990.0                 Dick Tracy   67952401  Jun 15-17
# ..      ...                        ...        ...        ...
# 442  2019.0  Spider-Man: Far from Home  174209668    Jul 5-7
# 443  2019.0              Downton Abbey  113373910  Sep 20-22
# 449  2019.0                      Joker  142713298    Oct 4-6
# 450  2019.0                     Midway  100490654   Nov 8-10
# 452  2020.0          Bad Boys for Life  148594253  Jan 17-19
#
#             Distributor       Budget imdb_title_id date_published  \
# 0          Warner Bros.   39000000.0     tt0086393      6/17/1983
# 2           Walt Disney   20000000.0     tt0094889      1/18/1989
# 7          Warner Bros.   35000000.0     tt0096895     10/20/1989
# 8    Paramount Pictures   30000000.0     tt0097481     11/17/1989
# 11          Walt Disney   47000000.0     tt0099422      10/5/1990
# ..                  ...          ...           ...            ...
# 442       Sony Pictures  160000000.0     tt6320628      7/10/2019
# 443      Focus Features   13000000.0     tt6398184     10/24/2019
# 449        Warner Bros.   55000000.0     tt7286456      10/3/2019
# 450           Lionsgate  100000000.0     tt6924650     11/27/2019
# 452       Sony Pictures   90000000.0     tt1502397      2/20/2020
#
#                          genre  duration                        country  \
# 0    Action, Adventure, Comedy       125                        UK, USA
# 2       Comedy, Drama, Romance       104                    USA, Canada
# 7            Action, Adventure       126                        USA, UK
# 8         Comedy, Crime, Drama       116                            USA
# 11       Action, Comedy, Crime       105                            USA
# ..                         ...       ...                            ...
# 442  Action, Adventure, Sci-Fi       129                            USA
# 443             Drama, Romance       122                        UK, USA
# 449     Crime, Drama, Thriller       122                    USA, Canada
# 450   Action, Adventure, Drama       138  China, Hong Kong, Canada, USA
# 452      Action, Comedy, Crime       124                    USA, Mexico
#
#                            language                     director  avg_vote  \
# 0         English, Italian, Spanish               Richard Lester       5.0
# 2    English, Spanish Sign Language              Roger Donaldson       5.9
# 7          English, French, Spanish                   Tim Burton       7.5
# 8                           English                 Eddie Murphy       6.1
# 11                          English                Warren Beatty       6.1
# ..                              ...                          ...       ...
# 442         English, Italian, Czech                    Jon Watts       7.5
# 443                         English               Michael Engler       7.4
# 449                         English                Todd Phillips       8.5
# 450     English, Japanese, Mandarin              Roland Emmerich       6.7
# 452                English, Spanish  Adil El Arbi, Bilall Fallah       6.6
#
#       votes  reviews_from_users  reviews_from_critics
# 0     63179               262.0                 119.0
# 2     77870               130.0                  60.0
# 7    332356               934.0                 229.0
# 8     19829                75.0                  26.0
# 11    56659               194.0                 101.0
# ..      ...                 ...                   ...
# 442  304708              2041.0                 415.0
# 443   35846               441.0                 174.0
# 449  855097             10472.0                 698.0
# 450   57789               946.0                 174.0
# 452  111557              1072.0                 238.0
#
# [304 rows x 17 columns]

# %%
#scatter plot to look for correlation between budget and user rating

plt.scatter(m_combine_fd['Budget'], m_combine_fd['avg_vote'], edgecolors = "black")
plt.ylabel('average user vote')
plt.xlabel('budget (x 10^8)')
plt.show()

r_val = st.pearsonr(m_combine_fd['Budget'], m_combine_fd['avg_vote'])

print(f'The correlation is {r_val[0]}')
# Out:
# The correlation is 0.28373290387529404

# %%
#scatter plot to look at opening revenue vs vote counts 

plt.scatter(m_combine_fd['Opening '], m_combine_fd['avg_vote'], edgecolors = "black")
plt.ylabel('average user vote')
plt.xlabel('opening revenue (x 10^8)')
plt.show()

r_val2 = st.pearsonr(m_combine_fd['Opening '], m_combine_fd['avg_vote'])

print(f'The correlation is {r_val2[0]}')
# Out:
# The correlation is 0.2749623813539261

# %%
#plot to look at vote counts and budget

plt.scatter(m_combine_fd['Budget'], m_combine_fd['votes'], edgecolors = "black")
plt.ylabel('votes')
plt.xlabel('budget (x 10^8)')
plt.show()

r_val3 = st.pearsonr(m_combine_fd['Budget'], m_combine_fd['votes'])
print(f'The correlation is {r_val3[0]}')
# Out:
# The correlation is 0.3923550625694008

# %%
plt.scatter(m_combine_fd['Opening '], m_combine_fd['votes'], edgecolors = "black")
plt.ylabel('votes')
plt.xlabel('opening revenue (x 10^8)')
plt.show()

r_val4 = st.pearsonr(m_combine_fd['Opening '], m_combine_fd['votes'])

print(f'The correlation is {r_val4[0]}')
# Out:
# The correlation is 0.3841310103392916

# %%
#m_df.to_csv('desktop/IMDb_fixed_years_data.csv', index = False)

# %%
m_combine_fd.describe()
# Out:
#               Year      Opening         Budget    duration    avg_vote  \
# count   304.000000  3.040000e+02  3.040000e+02  304.000000  304.000000
# mean   2007.171053  1.184722e+08  9.276217e+07  116.802632    6.664803
# std       7.493254  4.799676e+07  6.662899e+07   19.890970    0.950028
# min    1983.000000  4.825606e+07  3.000000e+06   81.000000    2.400000
# 25%    2002.000000  8.222551e+07  4.200000e+07  103.000000    6.100000
# 50%    2008.000000  1.110154e+08  7.500000e+07  115.000000    6.700000
# 75%    2013.000000  1.419442e+08  1.375000e+08  129.000000    7.300000
# max    2020.000000  3.964699e+08  3.560000e+08  194.000000    8.800000
#
#               votes  reviews_from_users  reviews_from_critics
# count  3.040000e+02          304.000000            304.000000
# mean   3.149994e+05          992.049342            297.226974
# std    2.846870e+05         1121.576937            178.619877
# min    9.071000e+03           35.000000             16.000000
# 25%    1.190128e+05          376.000000            153.000000
# 50%    2.400595e+05          654.500000            247.500000
# 75%    4.142005e+05         1300.750000            416.000000
# max    2.002816e+06        10472.000000            813.000000

# %%
#looking at the number of votes movies in the combined dataframe got on average

com_votes = m_combine_fd[["votes"]].copy()

boxplot = com_votes.boxplot(grid = False)

# %%
med = com_votes.median()

print(f'The median number of votes in the combined set is {med}')
# Out:
# The median number of votes in the combined set is votes    240059.5
# dtype: float64
